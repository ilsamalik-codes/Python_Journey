# %%
import kagglehub
path = kagglehub.dataset_download("patrickb1912/ipl-complete-dataset-20082020")
# Out:
# Using Colab cache for faster access to the 'ipl-complete-dataset-20082020' dataset.

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(path + "/matches.csv")

# %%
data
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(3)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
# 2       Rajasthan Royals             Rajasthan Royals           bat
#
#                   winner   result  result_margin  target_runs  target_overs  \
# ...

# %%
data.tail(1)
# Out:
#            id season     city        date match_type player_of_match  \
# 1094  1426312   2024  Chennai  2024-05-26      Final        MA Starc
#
#                                          venue                team1  \
# 1094  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
#
#                       team2          toss_winner toss_decision  \
# 1094  Kolkata Knight Riders  Sunrisers Hyderabad           bat
#
#                      winner   result  result_margin  target_runs  \
# 1094  Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over method        umpire1      umpire2
# 1094          20.0          N    NaN  J Madanagopal  Nitin Menon

# %%
data.shape
# Out:
# (1095, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
data.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
data['winner']
# Out:
# 0             Kolkata Knight Riders
# 1               Chennai Super Kings
# 2                  Delhi Daredevils
# 3       Royal Challengers Bangalore
# 4             Kolkata Knight Riders
#                    ...
# 1090            Sunrisers Hyderabad
# 1091          Kolkata Knight Riders
# 1092               Rajasthan Royals
# 1093            Sunrisers Hyderabad
# 1094          Kolkata Knight Riders
# Name: winner, Length: 1095, dtype: object

# %%
data[['team1','team2','winner']]
# Out:
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                            winner
# 0           Kolkata Knight Riders
# 1             Chennai Super Kings
# 2                Delhi Daredevils
# 3     Royal Challengers Bangalore
# ...

# %%
data.iloc[1:3]
# Out:
#        id   season        city        date match_type player_of_match  \
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                         venue             team1  \
# 1  Punjab Cricket Association Stadium, Mohali   Kings XI Punjab
# 2                            Feroz Shah Kotla  Delhi Daredevils
#
#                  team2          toss_winner toss_decision  \
# 1  Chennai Super Kings  Chennai Super Kings           bat
# 2     Rajasthan Royals     Rajasthan Royals           bat
#
#                 winner   result  result_margin  target_runs  target_overs  \
# 1  Chennai Super Kings     runs           33.0        241.0          20.0
# 2     Delhi Daredevils  wickets            9.0        130.0          20.0
#
#   super_over method    umpire1         umpire2
# 1          N    NaN  MR Benson      SL Shastri
# 2          N    NaN  Aleem Dar  GA Pratapkumar

# %%
mask=data['city']=='Hyderabad'
data[mask].shape
# Out:
# (77, 20)

# %%
data.iloc[:,[4,5,10]]
# Out:
#        match_type  player_of_match toss_decision
# 0          League      BB McCullum         field
# 1          League       MEK Hussey           bat
# 2          League      MF Maharoof           bat
# 3          League       MV Boucher           bat
# 4          League        DJ Hussey           bat
# ...           ...              ...           ...
# 1090       League  Abhishek Sharma           bat
# 1091  Qualifier 1         MA Starc           bat
# 1092   Eliminator         R Ashwin         field
# 1093  Qualifier 2    Shahbaz Ahmed         field
# 1094        Final         MA Starc           bat
#
# [1095 rows x 3 columns]

# %%
def get_city_match_count(city):
  mask=data['city']==city
  return data[mask].shape

# %%
get_city_match_count('Chennai')
# Out:
# (85, 20)

# %%
mask1=data['city']=='Hyderabad'
mask2=data['date']>'2023'

data[mask1 & mask2].shape[0]
# Out:
# 13

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Sunrisers Hyderabad             88
# Kings XI Punjab                 88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Punjab Kings                    24
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
# the pandas plot()
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['result_margin'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
myseries=data['winner'].value_counts()

# %%
myseries.head()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Name: count, dtype: int64

# %%
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values(ascending=False).head()
# Out:
# Mumbai Indians                 261
# Kolkata Knight Riders          251
# Royal Challengers Bangalore    240
# Chennai Super Kings            238
# Rajasthan Royals               221
# Name: count, dtype: int64

# %%
#ascendin=false,inplace=true is for permanant changes in data

# %%
data.sort_values(['city','date'],ascending=[True,False])
# Out:
#           id season       city        date match_type player_of_match  \
# 870  1254088   2021  Abu Dhabi  2021-10-08     League    Ishan Kishan
# 867  1254095   2021  Abu Dhabi  2021-10-06     League   KS Williamson
# 861  1254089   2021  Abu Dhabi  2021-10-02     League      RD Gaikwad
# 857  1254099   2021  Abu Dhabi  2021-09-28     League      KA Pollard
# 853  1254098   2021  Abu Dhabi  2021-09-26     League       RA Jadeja
# ..       ...    ...        ...         ...        ...             ...
# 406   729295   2014        NaN  2014-04-22     League      GJ Maxwell
# 404   729291   2014        NaN  2014-04-20     League      GJ Maxwell
# 402   729287   2014        NaN  2014-04-19     League        PA Patel
# 403   729289   2014        NaN  2014-04-19     League       JP Duminy
# 399   729281   2014        NaN  2014-04-17     League       YS Chahal
#
#                                    venue                        team1  \
# ...

# %%
data.drop_duplicates(subset=['city'])
# Out:
#            id   season            city        date match_type  \
# 0      335982  2007/08       Bangalore  2008-04-18     League
# 1      335983  2007/08      Chandigarh  2008-04-19     League
# 2      335984  2007/08           Delhi  2008-04-19     League
# 3      335985  2007/08          Mumbai  2008-04-20     League
# 4      335986  2007/08         Kolkata  2008-04-20     League
# 5      335987  2007/08          Jaipur  2008-04-21     League
# 6      335988  2007/08       Hyderabad  2008-04-22     League
# 7      335989  2007/08         Chennai  2008-04-23     League
# 58     392181     2009       Cape Town  2009-04-18     League
# 62     392185     2009  Port Elizabeth  2009-04-20     League
# 63     392186     2009          Durban  2009-04-21     League
# 73     392198     2009       Centurion  2009-04-28     League
# 78     392203     2009     East London  2009-05-01     League
# 81     392206     2009    Johannesburg  2009-05-02     League
# ...

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (37, 20)

# %%
data.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season')
# Out:
#        season                 winner
# 57    2007/08       Rajasthan Royals
# 114      2009        Deccan Chargers
# 174   2009/10    Chennai Super Kings
# 247      2011    Chennai Super Kings
# 321      2012  Kolkata Knight Riders
# 397      2013         Mumbai Indians
# 457      2014  Kolkata Knight Riders
# 516      2015         Mumbai Indians
# 576      2016    Sunrisers Hyderabad
# 635      2017         Mumbai Indians
# 695      2018    Chennai Super Kings
# 755      2019         Mumbai Indians
# 815   2020/21         Mumbai Indians
# 875      2021    Chennai Super Kings
# 949      2022         Gujarat Titans
# 1023     2023    Chennai Super Kings
# 1094     2024  Kolkata Knight Riders

# %%
data.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
data.groupby('player_of_match')

# %%
winner=data.groupby('player_of_match')

# %%
winner.get_group('BB McCullum').shape
# Out:
# (5, 20)

# %%
winner['player_of_match'].sum().sort_values(ascending=False).head(10)
# Out:
# player_of_match
# Z Khan                                                          Z Khan
# Yuvraj Singh         Yuvraj SinghYuvraj SinghYuvraj SinghYuvraj Sin...
# Yash Thakur                                                Yash Thakur
# YS Chahal            YS ChahalYS ChahalYS ChahalYS ChahalYS ChahalY...
# YK Pathan            YK PathanYK PathanYK PathanYK PathanYK PathanY...
# YBK Jaiswal          YBK JaiswalYBK JaiswalYBK JaiswalYBK JaiswalYB...
# Washington Sundar                                    Washington Sundar
# WPUJC Vaas                                                  WPUJC Vaas
# WP Saha                            WP SahaWP SahaWP SahaWP SahaWP Saha
# WG Jacks                                                      WG Jacks
# Name: player_of_match, dtype: object

# %%
import kagglehub
path = kagglehub.dataset_download("manasgarg/ipl")
# Out:
# ...
# 100%|██████████| 1.01M/1.01M [00:00<00:00, 120MB/s]
# Extracting files...

# %%
matches=pd.read_csv(path + "/matches.csv")

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
matches.groupby('player_of_match')

# %%
mask=matches['player_of_match']=='BB McCullum'
matches[mask].shape
# Out:
# (5, 18)

# %%
matches.groupby('player_of_match').get_group('BB McCullum')
# Out:
#       id  season       city        date                  team1  \
# 59    60    2008  Bangalore  2008-04-18  Kolkata Knight Riders
# 246  247    2011     Mumbai  2011-04-15         Mumbai Indians
# 251  252    2011      Kochi  2011-04-18    Chennai Super Kings
# 520  521    2015    Chennai  2015-04-11    Chennai Super Kings
# 541  542    2015    Chennai  2015-04-25    Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 246         Kochi Tuskers Kerala         Kochi Tuskers Kerala         field
# 251         Kochi Tuskers Kerala         Kochi Tuskers Kerala         field
# 520          Sunrisers Hyderabad          Chennai Super Kings           bat
# 541              Kings XI Punjab          Chennai Super Kings           bat
#
#      result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
def run_scored(player):
  mask=matches['player_of_match']==player
  return matches[mask].shape

# %%
run_scored('BB McCullum')
# Out:
# (5, 18)

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.DataFrame({"names": ["harry","Ali"], "marks":["100","50"]})
df
# Out:
#    names marks
# 0  harry   100
# 1    Ali    50

# %%
matches=pd.read_csv(path + "/matches.csv")

# %%
matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
matches.dropna()
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
matches.rename(columns={"player_of_match": "POM"})
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
matches.merge(data,left_on='id',right_on='id').shape
# Out:
# (0, 37)

# %%
print(matches.shape)
print(data.shape)
# Out:
# (636, 18)
# (1095, 20)

# %%
import kagglehub
path = kagglehub.dataset_download("sudarshan24byte/online-food-dataset")
# Out:
# ...
# 100%|██████████| 3.37k/3.37k [00:00<00:00, 6.61MB/s]
# Extracting files...

# %%
import os

# List all files in the directory pointed to by 'path'
# print(os.listdir(path))

# The correct filename is 'onlinefoods.csv'
food = pd.read_csv(path + "/onlinefoods.csv")
display(food.head())
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
food.head(2)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
#
#   Output  Feedback Unnamed: 12
# 0    Yes  Positive         Yes
# 1    Yes  Positive         Yes

# %%
data.head(5)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
data.set_index('id',inplace=True)

# %%
data.reset_index(inplace=True)

# %%
#handling missing data

# %%
data.shape
# Out:
# (1095, 20)

# %%
data.dropna(axis=1,how='all').shape
# Out:
# (1095, 20)

# %%
data.fillna(0)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...
